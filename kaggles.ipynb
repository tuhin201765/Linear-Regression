# %%
import os
os.chdir(r'D:\pyc\Countries')

# %%
import pandas as pd

# %%
df = pd.read_csv('annual-enterprise-survey-2021-financial-year-provisional-csv.csv')

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.shape
# Out:
# (41715, 10)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...

# %%
df.describe()
# Out:
#               Year
# count  41715.00000
# mean    2017.00000
# std        2.58202
# min     2013.00000
# 25%     2015.00000
# 50%     2017.00000
# 75%     2019.00000
# max     2021.00000

# %%
df.values
# Out:
# array([[2021, 'Level 1', '99999', ..., 'Financial performance',
#         '757,504',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2021, 'Level 1', '99999', ..., 'Financial performance',
#         '674,890',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2021, 'Level 1', '99999', ..., 'Financial performance', '49,593',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        ...,
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '12',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '5',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
# ...

# %%
X = df.drop(columns=['Industry_code_ANZSIC06'])

# %%
X
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
Y = df['Year']
Y
# Out:
# 0        2021
# 1        2021
# 2        2021
# 3        2021
# 4        2021
#          ...
# 41710    2013
# 41711    2013
# 41712    2013
# 41713    2013
# 41714    2013
# Name: Year, Length: 41715, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3028\1199316915.py in <module>
#       1 model = DecisionTreeClassifier()
# ----> 2 model.fit(X, Y)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#
# ...

# %%
Z = df['Value']
Z
# Out:
# 0        757,504
# 1        674,890
# 2         49,593
# 3         33,020
# 4        654,404
#           ...
# 41710         52
# 41711         40
# 41712         12
# 41713          5
# 41714         46
# Name: Value, Length: 41715, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(Y, Z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3028\3494584518.py in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 model = DecisionTreeClassifier()
# ----> 3 model.fit(Y, Z)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41715 entries, 0 to 41714
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         41715 non-null  int64
#  1   Industry_aggregation_NZSIOC  41715 non-null  object
#  2   Industry_code_NZSIOC         41715 non-null  object
#  3   Industry_name_NZSIOC         41715 non-null  object
#  4   Units                        41715 non-null  object
#  5   Variable_code                41715 non-null  object
#  6   Variable_name                41715 non-null  object
#  7   Variable_category            41715 non-null  object
#  8   Value                        41715 non-null  object
#  9   Industry_code_ANZSIC06       41715 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.2+ MB

# %%
df['Units']
# Out:
# 0        Dollars (millions)
# 1        Dollars (millions)
# 2        Dollars (millions)
# 3        Dollars (millions)
# 4        Dollars (millions)
#                 ...
# 41710            Percentage
# 41711            Percentage
# 41712            Percentage
# 41713            Percentage
# 41714            Percentage
# Name: Units, Length: 41715, dtype: object

# %%
df.iloc[3000]
# Out:
# Year                                                               2021
# Industry_aggregation_NZSIOC                                     Level 1
# Industry_code_NZSIOC                                                 JJ
# Industry_name_NZSIOC           Information Media and Telecommunications
# Units                                                Dollars (millions)
# Variable_code                                                       H21
# Variable_name                                            Opening stocks
# Variable_category                                 Financial performance
# Value                                                               325
# Industry_code_ANZSIC06                              ANZSIC06 division J
# Name: 3000, dtype: object

# %%
df.Variable_category
# Out:
# 0        Financial performance
# 1        Financial performance
# 2        Financial performance
# 3        Financial performance
# 4        Financial performance
#                  ...
# 41710         Financial ratios
# 41711         Financial ratios
# 41712         Financial ratios
# 41713         Financial ratios
# 41714         Financial ratios
# Name: Variable_category, Length: 41715, dtype: object

# %%
df.Variable_category == 'Financial performance'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 41710    False
# 41711    False
# 41712    False
# 41713    False
# 41714    False
# Name: Variable_category, Length: 41715, dtype: bool

# %%
df2 = df[df.Variable_category == 'Financial performance']

# %%
df2.to_csv('Financial performance.csv')

# %%
df.Industry_name_NZSIOC
# Out:
# 0                    All industries
# 1                    All industries
# 2                    All industries
# 3                    All industries
# 4                    All industries
#                     ...
# 41710    Food product manufacturing
# 41711    Food product manufacturing
# 41712    Food product manufacturing
# 41713    Food product manufacturing
# 41714    Food product manufacturing
# Name: Industry_name_NZSIOC, Length: 41715, dtype: object

# %%
df2
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41692  2013                     Level 3                 ZZ11
# 41693  2013                     Level 3                 ZZ11
# 41694  2013                     Level 3                 ZZ11
# 41695  2013                     Level 3                 ZZ11
# 41696  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.iloc[1:456]
# Out:
#      Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 1    2021                     Level 1                99999
# 2    2021                     Level 1                99999
# 3    2021                     Level 1                99999
# 4    2021                     Level 1                99999
# 5    2021                     Level 1                99999
# ..    ...                         ...                  ...
# 451  2021                     Level 1                   BB
# 452  2021                     Level 1                   BB
# 453  2021                     Level 1                   BB
# 454  2021                     Level 1                   BB
# 455  2021                     Level 1                   BB
#
#     Industry_name_NZSIOC               Units Variable_code  \
# 1         All industries  Dollars (millions)           H04
# 2         All industries  Dollars (millions)           H05
# 3         All industries  Dollars (millions)           H07
# ...

# %%
df.Industry_aggregation_NZSIOC
# Out:
# 0        Level 1
# 1        Level 1
# 2        Level 1
# 3        Level 1
# 4        Level 1
#           ...
# 41710    Level 3
# 41711    Level 3
# 41712    Level 3
# 41713    Level 3
# 41714    Level 3
# Name: Industry_aggregation_NZSIOC, Length: 41715, dtype: object

# %%
df.Industry_aggregation_NZSIOC == 'Level 1'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 41710    False
# 41711    False
# 41712    False
# 41713    False
# 41714    False
# Name: Industry_aggregation_NZSIOC, Length: 41715, dtype: bool

# %%
df3 = df[df.Industry_name_NZSIOC == 'Agriculture, Forestry and Fishing']

# %%
df3.to_csv('Agriculture, Forestry and Fishing.csv',index = False)

# %%
X = df.drop(columns=['Industry_code_ANZSIC06'])
X
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3028\2444897107.py in <module>
# ----> 1 df3(X)
#
# TypeError: 'DataFrame' object is not callable

# %%
df.Value <= '20000'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41710    False
# 41711    False
# 41712     True
# 41713    False
# 41714    False
# Name: Value, Length: 41715, dtype: bool

# %%
df[df.Value >= '20000']
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41709  2013                     Level 3                 ZZ11
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...
