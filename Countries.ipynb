# %%
import os
os.chdir(r'D:\pyc\Countries')

# %%
import pandas as pd

# %%
df = pd.read_csv('countrycode.csv')

# %%
df.head(6)
# Out:
#      Country Name ISO2 ISO3 Top Level Domain FIPS  ISO Numeric  GeoNameID  \
# 0     Afghanistan   AF  AFG               af   AF            4  1149361.0
# 1         Albania   AL  ALB               al   AL            8   783754.0
# 2         Algeria   DZ  DZA               dz   AG           12  2589581.0
# 3  American Samoa   AS  ASM               as   AQ           16  5880801.0
# 4         Andorra   AD  AND               ad   AN           20  3041565.0
# 5          Angola   AO  AGO               ao   AO           24  3351879.0
#
#    E164 Phone Code Continent  ... Time Zone in Capital Currency  \
# 0    93         93      Asia  ...           Asia/Kabul  Afghani
# 1   355        355    Europe  ...        Europe/Tirane      Lek
# 2   213        213    Africa  ...       Africa/Algiers    Dinar
# 3     1      1-684   Oceania  ...    Pacific/Pago_Pago   Dollar
# 4   376        376    Europe  ...       Europe/Andorra     Euro
# ...

# %%
df.tail(6)
# Out:
#           Country Name ISO2 ISO3 Top Level Domain FIPS  ISO Numeric  \
# 234            Vietnam   VN  VNM               vn   VM          704
# 235  Wallis and Futuna   WF  WLF               wf   WF          876
# 236     Western Sahara   EH  ESH               eh   WI          732
# 237              Yemen   YE  YEM               ye   YM          887
# 238             Zambia   ZM  ZMB               zm   ZA          894
# 239           Zimbabwe   ZW  ZWE               zw   ZI          716
#
#      GeoNameID  E164 Phone Code Continent  ... Time Zone in Capital Currency  \
# 234  1562822.0    84         84      Asia  ...     Asia/Ho_Chi_Minh     Dong
# 235  4034749.0   681        681   Oceania  ...       Pacific/Wallis    Franc
# 236  2461445.0   212        212    Africa  ...      Africa/El_Aaiun   Dirham
# 237    69543.0   967        967      Asia  ...            Asia/Aden     Rial
# 238   895949.0   260        260    Africa  ...        Africa/Maputo   Kwacha
# ...

# %%
df.shape
# Out:
# (240, 21)

# %%
df.columns
# Out:
# Index(['Country Name', 'ISO2', 'ISO3', 'Top Level Domain', 'FIPS',
#        'ISO Numeric', 'GeoNameID', 'E164', 'Phone Code', 'Continent',
#        'Capital', 'Time Zone in Capital', 'Currency', 'Language Codes',
#        'Languages', 'Area KM2', 'Internet Hosts', 'Internet Users',
#        'Phones (Mobile)', 'Phones (Landline)', 'GDP'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Name          240 non-null    object
#  1   ISO2                  239 non-null    object
#  2   ISO3                  240 non-null    object
#  3   Top Level Domain      239 non-null    object
#  4   FIPS                  240 non-null    object
#  5   ISO Numeric           240 non-null    int64
#  6   GeoNameID             239 non-null    float64
#  7   E164                  240 non-null    int64
#  8   Phone Code            240 non-null    object
#  9   Continent             240 non-null    object
#  10  Capital               238 non-null    object
#  11  Time Zone in Capital  240 non-null    object
#  12  Currency              239 non-null    object
#  13  Language Codes        239 non-null    object
#  14  Languages             239 non-null    object
# ...

# %%
df.ISO3
# Out:
# 0      AFG
# 1      ALB
# 2      DZA
# 3      ASM
# 4      AND
#       ...
# 235    WLF
# 236    ESH
# 237    YEM
# 238    ZMB
# 239    ZWE
# Name: ISO3, Length: 240, dtype: object

# %%
df['Country Name']
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
#              ...
# 235    Wallis and Futuna
# 236       Western Sahara
# 237                Yemen
# 238               Zambia
# 239             Zimbabwe
# Name: Country Name, Length: 240, dtype: object

# %%
df.iloc[234]
# Out:
# Country Name                                                      Vietnam
# ISO2                                                                   VN
# ISO3                                                                  VNM
# Top Level Domain                                                       vn
# FIPS                                                                   VM
# ISO Numeric                                                           704
# GeoNameID                                                       1562822.0
# E164                                                                   84
# Phone Code                                                             84
# Continent                                                            Asia
# Capital                                                             Hanoi
# Time Zone in Capital                                     Asia/Ho_Chi_Minh
# Currency                                                             Dong
# ...

# %%
df.Continent == "Asia"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 235    False
# 236    False
# 237     True
# 238    False
# 239    False
# Name: Continent, Length: 240, dtype: bool

# %%
df[df.Continent == "Asia"]
# Out:
#                        Country Name ISO2 ISO3 Top Level Domain FIPS  \
# 0                       Afghanistan   AF  AFG               af   AF
# 10                          Armenia   AM  ARM               am   AM
# 14                       Azerbaijan   AZ  AZE               az   AJ
# 16                          Bahrain   BH  BHR               bh   BA
# 17                       Bangladesh   BD  BGD               bd   BG
# 24                           Bhutan   BT  BTN               bt   BT
# 29   British Indian Ocean Territory   IO  IOT               io   IO
# 31                           Brunei   BN  BRN               bn   BX
# 35                         Cambodia   KH  KHM               kh   CB
# 43                            China   CN  CHN               cn   CH
# 44                 Christmas Island   CX  CXR               cx   KT
# 45                    Cocos Islands   CC  CCK               cc   CK
# 76                          Georgia   GE  GEO               ge   GG
# ...

# %%
df2 = df[df.Continent == "Asia"]

# %%
df2.to_csv('text.csv',index = False)

# %%
df.iloc[3:34]
# Out:
#                       Country Name ISO2 ISO3 Top Level Domain FIPS  \
# 3                   American Samoa   AS  ASM               as   AQ
# 4                          Andorra   AD  AND               ad   AN
# 5                           Angola   AO  AGO               ao   AO
# 6                         Anguilla   AI  AIA               ai   AV
# 7                       Antarctica   AQ  ATA               aq   AY
# 8              Antigua and Barbuda   AG  ATG               ag   AC
# 9                        Argentina   AR  ARG               ar   AR
# 10                         Armenia   AM  ARM               am   AM
# 11                           Aruba   AW  ABW               aw   AA
# 12                       Australia   AU  AUS               au   AS
# 13                         Austria   AT  AUT               at   AU
# 14                      Azerbaijan   AZ  AZE               az   AJ
# 15                         Bahamas   BS  BHS               bs   BF
# ...

# %%
df['Value'] = 1

# %%
df.to_csv('with value.csv',index=False)
